# %%
import requests
import matplotlib.pyplot as plt
import pandas as pd
import json

# %%
with open('../data/keys.json') as fi:
    credentials = json.load(fi)

# %%
api_key = credentials['etsy_key']

# %%
endpoint = 'https://openapi.etsy.com/v2/listings/active?api_key='+api_key

response = requests.get(endpoint)

# %%
response
# Out:
# <Response [200]>

# %%
res=response.json()
res
# Out:
# {'count': 50100,
#  'results': [{'listing_id': 920396414,
#    'state': 'active',
#    'user_id': 29585240,
#    'category_id': None,
#    'title': 'Wedding Invitation Template Set, Dusky Pink Floral, Wedding Invitation Suite, Printable, Fully Editable, Templett INSTANT Download',
# ...

# %%
def jprint(obj):
    # create a formatted string of the Python JSON object
    text = json.dumps(obj, sort_keys=True, indent=4)
    print(text)

jprint(response.json())
# Out:
# {
#     "count": 50100,
#     "pagination": {
#         "effective_limit": 25,
#         "effective_offset": 0,
#         "effective_page": 1,
#         "next_offset": 25,
#         "next_page": 2
#     },
#     "params": {
#         "accepts_gift_cards": "false",
#         "color": null,
#         "color_accuracy": 0,
#         "geo_level": "city",
#         "keywords": null,
#         "lat": null,
#         "limit": 25,
#         "location": null,
#         "lon": null,
#         "max_price": null,
#         "min_price": null,
#         "offset": 0,
#         "page": null,
#         "region": null,
#         "sort_on": "created",
#         "sort_order": "down",
#         "tags": null,
#         "taxonomy_id": null,
#         "translate_keywords": "false"
#     },
#     "results": [
#         {
#             "category_id": null,
#             "creation_tsz": 1654819132,
#             "currency_code": "USD",
# ...

# %%
#response.text --- dont need

# %%
res.keys()
# Out:
# dict_keys(['count', 'results', 'params', 'type', 'pagination'])

# %%
res['count']
# Out:
# 50100

# %%
contents = res['results']
contents
# Out:
# [{'listing_id': 920396414,
#   'state': 'active',
#   'user_id': 29585240,
#   'category_id': None,
#   'title': 'Wedding Invitation Template Set, Dusky Pink Floral, Wedding Invitation Suite, Printable, Fully Editable, Templett INSTANT Download',
# ...

# %%
res['params']
# Out:
# {'limit': 25,
#  'offset': 0,
#  'page': None,
#  'keywords': None,
#  'sort_on': 'created',
#  'sort_order': 'down',
#  'min_price': None,
#  'max_price': None,
#  'color': None,
#  'color_accuracy': 0,
#  'tags': None,
#  'taxonomy_id': None,
#  'location': None,
#  'lat': None,
#  'lon': None,
#  'region': None,
#  'geo_level': 'city',
#  'accepts_gift_cards': 'false',
#  'translate_keywords': 'false'}

# %%
res['params']['geo_level']
# Out:
# 'city'

# %%
res['type']
# Out:
# 'Listing'

# %%
res['pagination']
# Out:
# {'effective_limit': 25,
#  'effective_offset': 0,
#  'next_offset': 25,
#  'effective_page': 1,
#  'next_page': 2}

# %%
#res['count'].keys()

# %%
#res['results'].keys()

# %%
res['params'].keys()
# Out:
# dict_keys(['limit', 'offset', 'page', 'keywords', 'sort_on', 'sort_order', 'min_price', 'max_price', 'color', 'color_accuracy', 'tags', 'taxonomy_id', 'location', 'lat', 'lon', 'region', 'geo_level', 'accepts_gift_cards', 'translate_keywords'])

# %%
#res['type'].keys()

# %%
res['pagination'].keys()
# Out:
# dict_keys(['effective_limit', 'effective_offset', 'next_offset', 'effective_page', 'next_page'])

# %%
res['params']['keywords']

# %%
etsy_contents_df = pd.DataFrame(contents)
etsy_contents_df
# Out:
#     listing_id   state    user_id category_id  \
# 0    920396414  active   29585240        None
# 1   1193793400  active  316566192        None
# 2    688544706  active   20245000        None
# 3   1248499783  active  150327787        None
# 4   1033674869  active  268262456        None
# 5   1234571772  active   40309293        None
# 6   1234571770  active  520627904        None
# 7   1208557751  active  624627575        None
# 8    988168474  active  434155662        None
# 9   1234571746  active    7357581        None
# 10  1108117813  active   52445725        None
# 11   687395102  active   46641253        None
# 12  1117103452  active  156597183        None
# 13  1129639335  active  274601012        None
# 14  1218808270  active  366761698        None
# 15  1150565227  active   52445725        None
# 16  1151061140  active  288862437        None
# 17  1243417151  active  163710597        None
# 18   804124134  active   10667076        None
# ...
