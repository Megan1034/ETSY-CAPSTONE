# %%
import requests
import matplotlib.pyplot as plt
import pandas as pd
import json
from requests.auth import HTTPBasicAuth
from pandas import json_normalize

# %%
# Opening JSON file
df = open('../data/EtsyV3.json', encoding="mbcs")
# returns JSON object as a dictionary
df_json = json.load(df)

df_json = pd.DataFrame(dict([(k,pd.Series(v)) for k,v in df_json.items()]))

df_json = df_json.T

#genres = genres.dropna()
#genres = genres.reset_index(drop=True)
#genres.columns = ['artist', 'genre']

df_json
# Out:
#                                                              0  \
# openapi                                                  3.0.2
# info                                                       NaN
# servers      {'url': 'https://openapi.etsy.com', 'descripti...
# security                                       {'api_key': []}
# tags                                          {'name': 'User'}
# x-tagGroups  {'name': 'Listing Management', 'tags': ['Buyer...
# paths                                                      NaN
# components                                                 NaN
#
#                                                 1  \
# openapi                                       NaN
# info                                          NaN
# servers                                       NaN
# security                                      NaN
# tags                      {'name': 'UserAddress'}
# x-tagGroups  {'name': 'Other', 'tags': ['Other']}
# paths                                         NaN
# components                                    NaN
#
#                                                              2  \
# openapi                                                    NaN
# info                                                       NaN
# servers                                                    NaN
# security                                                   NaN
# tags                     {'name': 'Shop Receipt Transactions'}
# x-tagGroups  {'name': 'Payment Management', 'tags': ['Ledge...
# paths                                                      NaN
# components                                                 NaN
#
#                                                              3  \
# openapi                                                    NaN
# info                                                       NaN
# servers                                                    NaN
# security                                                   NaN
# tags                                         {'name': 'Other'}
# x-tagGroups  {'name': 'Receipt Management', 'tags': ['Shop ...
# paths                                                      NaN
# components                                                 NaN
#
#                                                              4  \
# openapi                                                    NaN
# info                                                       NaN
# servers                                                    NaN
# security                                                   NaN
# tags                                          {'name': 'Shop'}
# x-tagGroups  {'name': 'Review Management', 'tags': ['Review']}
# paths                                                      NaN
# components                                                 NaN
#
#                                                              5  \
# openapi                                                    NaN
# info                                                       NaN
# servers                                                    NaN
# security                                                   NaN
# tags                          {'name': 'Shop ShippingProfile'}
# x-tagGroups  {'name': 'Shipping Management', 'tags': ['Shop...
# paths                                                      NaN
# components                                                 NaN
#
#                                                              6  \
# openapi                                                    NaN
# info                                                       NaN
# servers                                                    NaN
# security                                                   NaN
# tags                                  {'name': 'Shop Section'}
# x-tagGroups  {'name': 'Shop Management', 'tags': ['Shop', '...
# paths                                                      NaN
# components                                                 NaN
#
#                                                              7  \
# openapi                                                    NaN
# info                                                       NaN
# servers                                                    NaN
# security                                                   NaN
# tags                                   {'name': 'ShopListing'}
# x-tagGroups  {'name': 'User Management', 'tags': ['User', '...
# paths                                                      NaN
# components                                                 NaN
#
#                                               8                           9  \
# openapi                                     NaN                         NaN
# info                                        NaN                         NaN
# servers                                     NaN                         NaN
# security                                    NaN                         NaN
# tags         {'name': 'Shop ProductionPartner'}  {'name': 'SellerTaxonomy'}
# x-tagGroups                                 NaN                         NaN
# paths                                       NaN                         NaN
# components                                  NaN                         NaN
#
#              ...   /v3/application/user/addresses/{user_address_id}  \
# openapi      ...                                                NaN
# info         ...                                                NaN
# servers      ...                                                NaN
# security     ...                                                NaN
# tags         ...                                                NaN
# x-tagGroups  ...                                                NaN
# paths        ...  {'delete': {'operationId': 'Api_Application_Op...
# components   ...                                                NaN
#
#                                /v3/application/users/{user_id}  \
# openapi                                                    NaN
# info                                                       NaN
# servers                                                    NaN
# security                                                   NaN
# tags                                                       NaN
# x-tagGroups                                                NaN
# paths        {'get': {'operationId': 'getUser', 'descriptio...
# components                                                 NaN
#
#                          /v3/application/users/{user_id}/shops  \
# openapi                                                    NaN
# info                                                       NaN
# servers                                                    NaN
# security                                                   NaN
# tags                                                       NaN
# x-tagGroups                                                NaN
# paths        {'get': {'operationId': 'getShopByOwnerUserId'...
# components                                                 NaN
#
#                                       contact  \
# openapi                                   NaN
# info         {'email': 'developers@etsy.com'}
# servers                                   NaN
# security                                  NaN
# tags                                      NaN
# x-tagGroups                               NaN
# paths                                     NaN
# components                                NaN
#
#                                                    description  \
# openapi                                                    NaN
# info         <div class="wt-text-body-01"><p class="wt-pt-x...
# servers                                                    NaN
# security                                                   NaN
# tags                                                       NaN
# x-tagGroups                                                NaN
# paths                                                      NaN
# components                                                 NaN
#
#                                                        schemas  \
# openapi                                                    NaN
# info                                                       NaN
# servers                                                    NaN
# security                                                   NaN
# tags                                                       NaN
# x-tagGroups                                                NaN
# paths                                                      NaN
# components   {'BuyerTaxonomyNodes': {'type': 'object', 'des...
#
#                                                securitySchemes  \
# openapi                                                    NaN
# info                                                       NaN
# servers                                                    NaN
# security                                                   NaN
# tags                                                       NaN
# x-tagGroups                                                NaN
# paths                                                      NaN
# components   {'api_key': {'type': 'apiKey', 'name': 'x-api-...
#
#                              termsOfService             title version
# openapi                                 NaN               NaN     NaN
# info         https://www.etsy.com/legal/api  Etsy Open API v3   3.0.0
# servers                                 NaN               NaN     NaN
# security                                NaN               NaN     NaN
# tags                                    NaN               NaN     NaN
# x-tagGroups                             NaN               NaN     NaN
# paths                                   NaN               NaN     NaN
# components                              NaN               NaN     NaN
#
# [8 rows x 89 columns]
