# %%
import requests
import matplotlib.pyplot as plt
import pandas as pd
import json
import re
from requests.auth import HTTPBasicAuth
from pandas import json_normalize

# %%
PnP_shops_csv = pd.read_csv("..\data\shop_info.csv")
PnP_shops_csv
# Out:
#       Unnamed: 0   shop_id            shop_name    user_id  create_date  \
# 0              0   5627890            tinoiseau    7891149   1250485197
# 1              1   6579872  DaydreamPaperStudio   14823706   1319533134
# 2              2   9039454         LettersToYou   43040627   1433462463
# 3              3   5325270       luciepritchard    6027215   1215602911
# 4              4  11704327          M2Originals   72915631   1480455584
# ...          ...       ...                  ...        ...          ...
# 2096        2096  17781165    StoriesBySharpies  159534793   1529176714
# 2097        2097  14051083    OverflowByMelissa   18247583   1494443900
# 2098        2098  23565130           YourDayDIY  313931824   1629750978
# 2099        2099  21820580       ByDesignCustom  102102587   1575872311
# 2100        2100  23130914    WhiteBirdDesignCo    9244179   1591720449
#
#       created_timestamp                                              title  \
# ...

# %%
PnP_shops_csv.tail()
# Out:
#       Unnamed: 0   shop_id          shop_name    user_id  create_date  \
# 2096        2096  17781165  StoriesBySharpies  159534793   1529176714
# 2097        2097  14051083  OverflowByMelissa   18247583   1494443900
# 2098        2098  23565130         YourDayDIY  313931824   1629750978
# 2099        2099  21820580     ByDesignCustom  102102587   1575872311
# 2100        2100  23130914  WhiteBirdDesignCo    9244179   1591720449
#
#       created_timestamp                                              title  \
# 2096         1529176714          prints, stationery, and anything lettered
# 2097         1494443900                                Overflow by Melissa
# 2098         1629750978                        Premium Printable Templates
# 2099         1575872311                           Create a life you love ✨
# 2100         1591720449  Christian Art, Sticker Sheets, Decals and Bibl...
#
#                                            announcement currency_code  \
# ...

# %%
PnP_shops_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2101 entries, 0 to 2100
# Data columns (total 48 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unnamed: 0                         2101 non-null   int64
#  1   shop_id                            2101 non-null   int64
#  2   shop_name                          2101 non-null   object
#  3   user_id                            2101 non-null   int64
#  4   create_date                        2101 non-null   int64
#  5   created_timestamp                  2101 non-null   int64
#  6   title                              1952 non-null   object
#  7   announcement                       1448 non-null   object
#  8   currency_code                      2101 non-null   object
#  9   is_vacation                        2101 non-null   bool
#  10  vacation_message                   997 non-null    object
# ...

# %%
shops_reviews = PnP_shops_csv.sort_values(by=['review_count', 'review_average'], ascending= [False, False])
shops_reviews
# Out:
#       Unnamed: 0   shop_id           shop_name    user_id  create_date  \
# 1558        1558   9609713           904Custom   49342455   1402494464
# 59            59  19242740      MandyLynnPlans  193982286   1547861619
# 1952        1952  12657318        PetalPaperCo   83335034   1457143731
# 288          288  17771982      JennyVstickers  155070084   1528076066
# 313          313  14474067     UnmeasuredEvent   25165126   1485732457
# ...          ...       ...                 ...        ...          ...
# 2084        2084  33899973        Calligradini   22283124   1642107512
# 2089        2089  19024633  ShastaMarieDesigns   61177809   1546612979
# 2091        2091  22189440      AbiBryanDesign   60000976   1583353667
# 2092        2092   9321629       MintAndClover   46093955   1588630841
# 2096        2096  17781165   StoriesBySharpies  159534793   1529176714
#
#       created_timestamp                                              title  \
# ...

# %%
PnP_shops_csv.describe()
# Out:
#         Unnamed: 0       shop_id       user_id   create_date  \
# count  2101.000000  2.101000e+03  2.101000e+03  2.101000e+03
# mean   1050.000000  1.600947e+07  1.226313e+08  1.491155e+09
# std     606.650778  7.357620e+06  1.358203e+08  1.069707e+08
# min       0.000000  5.025371e+06  4.620000e+02  1.127466e+09
# 25%     525.000000  1.003288e+07  2.499063e+07  1.427342e+09
# 50%    1050.000000  1.496966e+07  7.438848e+07  1.504958e+09
# 75%    1575.000000  2.114713e+07  1.620252e+08  1.581469e+09
# max    2100.000000  3.568789e+07  6.399174e+08  1.652221e+09
#
#        created_timestamp   update_date  updated_timestamp  \
# count       2.101000e+03  2.101000e+03       2.101000e+03
# mean        1.491155e+09  1.654553e+09       1.654553e+09
# std         1.069707e+08  3.525952e+06       3.525952e+06
# min         1.127466e+09  1.567600e+09       1.567600e+09
# 25%         1.427342e+09  1.654998e+09       1.654998e+09
# 50%         1.504958e+09  1.655682e+09       1.655682e+09
# ...
