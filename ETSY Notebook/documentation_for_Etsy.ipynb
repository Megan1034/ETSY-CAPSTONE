# %%
import requests
import matplotlib.pyplot as plt
import pandas as pd
import json
from requests.auth import HTTPBasicAuth
from pandas import json_normalize

# %%
# Opening JSON file
df = open('../data/EtsyV3.json', encoding="mbcs")
# returns JSON object as a dictionary
df_json = json.load(df)

df_json = pd.DataFrame(dict([(k,pd.Series(v)) for k,v in df_json.items()]))

df_json = df_json.T

#genres = genres.dropna()
#df_json = df_json.reset_index(drop=False)
#genres.columns = ['artist', 'genre']

df_json
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\MEGANG~1\AppData\Local\Temp/ipykernel_20960/2537324195.py in <module>
#      12 #genres.columns = ['artist', 'genre']
#      13
# ---> 14 pd.json_normalize(df_json, max_level=1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\json\_normalize.py in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     436
#     437     if record_path is None:
# --> 438         if any([isinstance(x, dict) for x in y.values()] for y in data):
#     439             # naive normalization, this is idempotent for flat records
#     440             # and potentially will inflate the data considerably for
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\json\_normalize.py in <genexpr>(.0)
#     436
#     437     if record_path is None:
# ...

# %%
pd.set_option('display.max_rows', None)
df_json = df_json.swapaxes('index', 'columns', copy=True)
df_json
# Out:
#                                                    openapi  \
# 0                                                    3.0.2
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
# 6                                                      NaN
# 7                                                      NaN
# 8                                                      NaN
# 9                                                      NaN
# 10                                                     NaN
# 11                                                     NaN
# 12                                                     NaN
# 13                                                     NaN
# 14                                                     NaN
# ...

# %%
df_json.to_csv('df_json.csv')
